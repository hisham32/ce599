# %% [markdown]
# # Mapping
#
# Transportation is about getting from place A to place B.  Therefore, most transportation data has a spatial component to it.  It is nice to be able to put these data on a map and see what is going on.  It is even better if we can put it on a map and interact with the data.  It would be even cooler if we could put our interactive map on a website to show it off!
#
# To do this, we are going to use a package called folium.  You can find the documentation here:
#
# https://folium.readthedocs.io/en/latest/
#
# And access it on github here:
#
# https://github.com/python-visualization/folium

# %% [markdown]
# ### Credits
#
# This lesson draws from the folium quickstart notebook, and from Vik Paruchuri DataQuest lesson:
#
# https://www.dataquest.io/blog/python-data-visualization-libraries/

# %% [markdown]
# ### A side note on static mapping
#
# Sometimes you may want to create a static map instead of an interactive map.  Interactive maps are nice for exploring your data, but static maps work well for an image that you can insert into a paper.  If you want to create static maps, then basemap is a good tool.  Here is a nice lesson focused on mapping earthquake activity:
#
# http://introtopython.org/visualization_earthquakes.html

# %% [markdown]
# ### OK, back to interactive mapping, because that's fun...
#
# It turns out that folium doesn't do much itself.  It is just a wrapper around something called leafletjs.  You can read more about that here:
#
# http://leafletjs.com/index.html
#
# Leaflet is a library in the JavaScript language.  JavaScript is the language used for most web applications.  We could do the same thing using JavaScript and leaflet directly, but then we would have to learn the syntax for another language.  That might not be too hard, but to keep it simple, we'll stick to the python wrapper for now.  It is good to be aware of, though, because if you want more options than folium allows, you can go directly to leaflet.
#
# What makes this possible is the fact that leaflet has a well-defined API.  That means that we can pass data back and forth, even from a different language.

# %% [markdown]
# ### Setup
#
# Start by installing folium using pip.  At a command prompt, type:
#
#     pip install folium
#
# Hmm...when I tried this on my desktop, I get an error that says:
#
#     PermissionError: [WinError 5] Access is denied: 'c:\\program files\\anaconda3\\Lib\\site-packages\\folium'
#
# It seems that it is trying to install something in the program files directory, which Windows has protected.  This will depend on the security settings on your machine.  If you get this error, open a command prompt as an administrator.  In the windows search bar, type cmd.  When you see the command prompt, right click, and select run as administrator.
#
# This did the trick, and now I get:
#
#     Successfully installed folium-0.2.1
#
# In addition, let's go to github and clone the folium repository (https://github.com/python-visualization/folium) to our desktop.  This gives us the source code on our local machine.  What we're really interested in is the examples folder, which gives us a bunch of jupyter notebooks showing how to do different stuff.  You are welcome to explore these as needed.
#
# You also need to install geopandas, which will make it easier to work with goegraphic data.  The pip installer doesn't work (the long explanation is here: http://geoffboeing.com/2014/09/using-geopandas-windows/), so we'll install using anaconda.  Type:
#
#     conda install -c conda-forge geopandas

# %% [markdown]
# Getting Started
# ---------------
#
# To create a base map, simply pass your starting coordinates to Folium:

# %%
import folium

# %%
m = folium.Map(location=[38.034,-84.500])

# %% [markdown]
# to display it in your notebook, just ask for the object representation.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# To save it in a file

# %%
m.save('lex.html')

# %% [markdown]
# We can use different backgrounds, or tilesets.  Several are built in.  Options include Stamen Terrain, Stamen Toner, Mapbox Bright, and Mapbox Control room tiles.

# %%
folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Pick one you like and work with that for the rest of the class.

# %% [markdown]
# Folium also supports Cloudmade and Mapbox custom tilesets- simply pass your key to the API_key keyword.  These are services where you can buy more backgrounds to make your maps look nice.
#
# ```python
# folium.Map(location=[45.5236, -122.6750],
#            tiles='Mapbox',
#            API_key='your.API.key')
# ```

# %% [markdown]
# ### Open flights
#
# Let's go back to our openflight data and make some maps.

# %%
import pandas as pd
import numpy as np

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

# Read in the airlines data.
airlines = pd.read_csv("airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

# Read in the routes data.
routes = pd.read_csv("routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %%
# let's peek at what we have
airports.head()
# Out:
#    id                                         name          city  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#             country iata  icao  latitude   longitude  altitude  timezone dst  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282      10.0   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U
#
#                      tz     type       source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
airlines.head()
# Out:
#    id                                          name alias iata icao callsign  \
# 0  -1                                       Unknown   NaN    -  NaN      NaN
# 1   1                                Private flight   NaN    -  NaN      NaN
# 2   2                                   135 Airways   NaN  NaN  GNL  GENERAL
# 3   3                                 1Time Airline   NaN   1T  RNX  NEXTIME
# 4   4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT      NaN
#
#           country active
# 0             NaN      Y
# 1             NaN      Y
# 2   United States      N
# 3    South Africa      Y
# 4  United Kingdom      N

# %%
routes.head()
# Out:
#   airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0      2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1      2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2      2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3      2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4      2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %% [markdown]
# Make a map with the airports on it.

# %%
# since there are a lot of airports, making the map can be slow
# so limit it to US airports
us_airports = airports[airports['country']=='United States']
len(us_airports)
# Out:
# 1435

# %%
# Get a basic world map.
# 30 centers the map E-W, and 0 is the equator
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# Loop through the airports, and draw each one as a marker on the map
# popup tells it what to display when you click on it
for name, row in us_airports.iterrows():
    
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.Marker([row["latitude"], row["longitude"]], popup=folium.Popup(row['name'],parse_html=True))
        marker.add_to(airports_map)
        
# Save it to a file (it's kinda big for the notebook)
airports_map.save('airports.html')

# %% [markdown]
# Hmm...it looks like there are airports everywhere!  Let's try again with smaller makers.
#
# We can also specify the color.  A list of custom colors is available here:
#
# http://www.w3schools.com/cssref/css_colors.asp

# %%
# over-write the airports_map, rather than just adding more markers to it. 
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# use circle markers this time, with custom size and color
for name, row in us_airports.iterrows():
        
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.CircleMarker([row["latitude"], row["longitude"]], 
                                     radius=5,
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     popup=folium.Popup(row['name'],parse_html=True))
        marker.add_to(airports_map)
        
airports_map.save('airports.html')

# %% [markdown]
# You can also select icons to use as markers.  That code would look like:
#
#     marker = folium.Marker([row["latitude"], row["longitude"]],
#                            icon=folium.Icon(icon='cloud'),
#                            popup=row['name'])
#
# The list of icons comes from something called bootstrap, and can be found here:
#
# http://www.bootstrapicons.com/

# %% [markdown]
# Or you can use clusters of markers to clean up the map.  This will group them when you zoom out, similar to a Craigslist map.  You can see how to do that here:
#
# https://ocefpaf.github.io/python4oceanographers/blog/2015/12/14/geopandas_folium/
#
# You can clean up the rest of this airports map as part of your homework this week.

# %%
airports_map = folium.Map(location=[30, 0], zoom_start=2)
from folium import IFrame
from folium.plugins import MarkerCluster

popups, locations = [], []
for index, row in us_airports.iterrows():
    if row["name"] != "South Pole Station":
        locations.append([row['latitude'], row['longitude']])
        columns=['id', 'name','city','latitude','longitude']
        iframe = folium.IFrame(pd.DataFrame(us_airports.loc[index,columns]).transpose().set_index("id").transpose().to_html(), width=250, height=150)
        popups.append(iframe)
    
h = folium.FeatureGroup(us_airports['country'])
h.add_child(MarkerCluster(locations=locations, popups=popups))
airports_map.add_child(h)
airports_map.save('us_airports.html')

# %%
mapa = folium.Map(location=[30, 0], zoom_start=2)
from folium import IFrame
from folium.plugins import MarkerCluster


df=airports['country'].unique()
for members in df:
    air = airports[airports['country']==members]
    popups, locations = [], []
        
    for index, row in air.iterrows():
        if row["name"] != "South Pole Station":
            locations.append([row['latitude'], row['longitude']])
            columns=['id', 'name', 'city', 'country', 'latitude', 'longitude']
            iframe = folium.IFrame(pd.DataFrame(air.loc[index,columns]).transpose().set_index('id').transpose().to_html(), width=250, height=150)
            popups.append(iframe)

    h = folium.FeatureGroup(members)
    h.add_child(MarkerCluster(locations=locations, popups=popups))
    h.add_to(mapa)
    
mapa.add_child(folium.LayerControl())    
mapa.save('airportsall.html')

# %% [markdown]
# Let's draw the routes, but since we have lots, let's just start with the routes departing Lexington.

# %%
# Select the LEX routes, then join the source airports
lex_routes = routes[(routes['source']=="LEX")]
lex_routes = pd.merge(lex_routes, airports, left_on='source_id', right_on='id', how='left')

# %%
# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
lex_routes = pd.merge(lex_routes, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])

# %%
# here is what our data looks like
lex_routes
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0      LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0      LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0      LEX     4017.0  ORD   3830.0         Y      0
# 4       AF       137.0      LEX     4017.0  ATL   3682.0         Y      0
# 5       DL      2009.0      LEX     4017.0  ATL   3682.0       NaN      0
# 6       DL      2009.0      LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0      LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0      LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0      LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0      LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX     4017.0  SFB   4167.0       NaN      0
# 14      KL      3090.0      LEX     4017.0  ATL   3682.0         Y      0
# 15      UA      5209.0      LEX     4017.0  IAH   3550.0         Y      0
# 16      UA      5209.0      LEX     4017.0  ORD   3830.0         Y      0
# 17      US      5265.0      LEX     4017.0  CLT   3876.0       NaN      0
# 18      US      5265.0      LEX     4017.0  DFW   3670.0       NaN      0
# 19      US      5265.0      LEX     4017.0  ORD   3830.0         Y      0
#
#       equipment  id_source     ...      iata_dest icao_dest latitude_dest  \
# 0           CRJ       4017     ...            ATL      KATL     33.636700
# 1       CR7 CRJ       4017     ...            CLT      KCLT     35.214001
# 2       ERD ER4       4017     ...            DFW      KDFW     32.896801
# 3       ERD ER4       4017     ...            ORD      KORD     41.978600
# 4       CRJ CR9       4017     ...            ATL      KATL     33.636700
# 5       M88 717       4017     ...            ATL      KATL     33.636700
# 6           CRJ       4017     ...            DCA      KDCA     38.852100
# 7   CR7 CRJ CR9       4017     ...            DTW      KDTW     42.212399
# 8           ERJ       4017     ...            LGA      KLGA     40.777199
# 9           CRJ       4017     ...            MSP      KMSP     44.882000
# 10          M80       4017     ...            FLL      KFLL     26.072599
# 11          M80       4017     ...            PGD      KPGD     26.920200
# 12          320       4017     ...            PIE      KPIE     27.910200
# 13      M80 320       4017     ...            SFB      KSFB     28.777599
# 14      CR9 CRJ       4017     ...            ATL      KATL     33.636700
# 15          ERJ       4017     ...            IAH      KIAH     29.984400
# 16      ERJ CRJ       4017     ...            ORD      KORD     41.978600
# 17          CR7       4017     ...            CLT      KCLT     35.214001
# 18          ERD       4017     ...            DFW      KDFW     32.896801
# 19      ERD ER4       4017     ...            ORD      KORD     41.978600
#
#    longitude_dest altitude_dest  timezone_dest  dst_dest           tz_dest  \
# 0      -84.428101          1026           -5.0         A  America/New_York
# 1      -80.943100           748           -5.0         A  America/New_York
# 2      -97.038002           607           -6.0         A   America/Chicago
# 3      -87.904800           672           -6.0         A   America/Chicago
# 4      -84.428101          1026           -5.0         A  America/New_York
# 5      -84.428101          1026           -5.0         A  America/New_York
# 6      -77.037697            15           -5.0         A  America/New_York
# 7      -83.353401           645           -5.0         A  America/New_York
# 8      -73.872597            21           -5.0         A  America/New_York
# 9      -93.221802           841           -6.0         A   America/Chicago
# 10     -80.152702             9           -5.0         A  America/New_York
# 11     -81.990501            26           -5.0         A  America/New_York
# 12     -82.687401            11           -5.0         A  America/New_York
# 13     -81.237503            55           -5.0         A  America/New_York
# 14     -84.428101          1026           -5.0         A  America/New_York
# 15     -95.341400            97           -6.0         A   America/Chicago
# 16     -87.904800           672           -6.0         A   America/Chicago
# 17     -80.943100           748           -5.0         A  America/New_York
# 18     -97.038002           607           -6.0         A   America/Chicago
# 19     -87.904800           672           -6.0         A   America/Chicago
#
#     type_dest       source
# 0     airport  OurAirports
# 1     airport  OurAirports
# 2     airport  OurAirports
# 3     airport  OurAirports
# 4     airport  OurAirports
# 5     airport  OurAirports
# 6     airport  OurAirports
# 7     airport  OurAirports
# 8     airport  OurAirports
# 9     airport  OurAirports
# 10    airport  OurAirports
# 11    airport  OurAirports
# 12    airport  OurAirports
# 13    airport  OurAirports
# 14    airport  OurAirports
# 15    airport  OurAirports
# 16    airport  OurAirports
# 17    airport  OurAirports
# 18    airport  OurAirports
# 19    airport  OurAirports
#
# [20 rows x 37 columns]

# %%
# It looks like source has some duplicate names.  Drop the values from the airports
# file ane keep the one from the routes file
lex_routes = lex_routes.drop(['source_y','source'], axis=1)
lex_routes = lex_routes.rename(columns={'source_x': 'source'})

# %%
# Let's keep only one route between each airport pair
# so we don't have a bunch of lines on top of each other
# The subset option tells it to consider just those columns when determining
# what is a duplicate. 

lex_routes = lex_routes.drop_duplicates(subset=['source', 'dest'])
lex_routes
# Out:
#    airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 6       DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 15      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
#
#       equipment  id_source    ...      country_dest iata_dest icao_dest  \
# 0           CRJ       4017    ...     United States       ATL      KATL
# 1       CR7 CRJ       4017    ...     United States       CLT      KCLT
# 2       ERD ER4       4017    ...     United States       DFW      KDFW
# 3       ERD ER4       4017    ...     United States       ORD      KORD
# 6           CRJ       4017    ...     United States       DCA      KDCA
# 7   CR7 CRJ CR9       4017    ...     United States       DTW      KDTW
# 8           ERJ       4017    ...     United States       LGA      KLGA
# 9           CRJ       4017    ...     United States       MSP      KMSP
# 10          M80       4017    ...     United States       FLL      KFLL
# 11          M80       4017    ...     United States       PGD      KPGD
# 12          320       4017    ...     United States       PIE      KPIE
# 13      M80 320       4017    ...     United States       SFB      KSFB
# 15          ERJ       4017    ...     United States       IAH      KIAH
#
#    latitude_dest longitude_dest  altitude_dest  timezone_dest  dst_dest  \
# 0      33.636700     -84.428101           1026           -5.0         A
# 1      35.214001     -80.943100            748           -5.0         A
# 2      32.896801     -97.038002            607           -6.0         A
# 3      41.978600     -87.904800            672           -6.0         A
# 6      38.852100     -77.037697             15           -5.0         A
# 7      42.212399     -83.353401            645           -5.0         A
# 8      40.777199     -73.872597             21           -5.0         A
# 9      44.882000     -93.221802            841           -6.0         A
# 10     26.072599     -80.152702              9           -5.0         A
# 11     26.920200     -81.990501             26           -5.0         A
# 12     27.910200     -82.687401             11           -5.0         A
# 13     28.777599     -81.237503             55           -5.0         A
# 15     29.984400     -95.341400             97           -6.0         A
#
#              tz_dest type_dest
# 0   America/New_York   airport
# 1   America/New_York   airport
# 2    America/Chicago   airport
# 3    America/Chicago   airport
# 6   America/New_York   airport
# 7   America/New_York   airport
# 8   America/New_York   airport
# 9    America/Chicago   airport
# 10  America/New_York   airport
# 11  America/New_York   airport
# 12  America/New_York   airport
# 13  America/New_York   airport
# 15   America/Chicago   airport
#
# [13 rows x 35 columns]

# %% [markdown]
# That looks better.  Now, let's create a map.  To avoid adding duplicate airports, we are going to use a container called a set.  A set is an unordered collection of unique elements.  This means we can keep adding LEX to the set, and end up with only 1 LEX in the end.

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # the parentheses in the indicate that we are adding a tuple to the route_set
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']        
        line = folium.PolyLine([(row["latitude_source"], row["longitude_source"]), 
                                (row["latitude_dest"], row["longitude_dest"])], 
                                weight=2, 
                                popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# That's cool.  But airplanes don't fly in a straight line.  They follow the great circle.  So when you fly from Chicago to London, you go over Greenland (which is really pretty on a clear day!).  Can we make the lines follow a great circle?
#
# It looks like there are some options here:
#
# http://gis.stackexchange.com/questions/47/what-tools-in-python-are-available-for-doing-great-circle-distance-line-creati
#
# Let's try one of them.

# %%
import pyproj

# when creating a function, it is good practice to define the API!
def getGreatCirclePoints(startlat, startlon, endlat, endlon): 
    """
    startlat - starting latitude 
    startlon - starting longitude 
    endlat   - ending latitude 
    endlon   - ending longitude 
    
    returns - a list of tuples, where each tuple is the lat-long for a point
              along the curve.  
    """
    # calculate distance between points
    g = pyproj.Geod(ellps='WGS84')
    (az12, az21, dist) = g.inv(startlon, startlat, endlon, endlat)

    # calculate line string along path with segments <= 20 km
    lonlats = g.npts(startlon, startlat, endlon, endlat,
                     1 + int(dist / 20000))

    # the npts function uses lon-lat, while the folium functions use lat-lon
    # This sort of thing is maddening!  What happens is the lines don't show
    # up on the map and you don't know why.  Learn from my mistakes
    latlons = []
    for lon_lat in lonlats: 
        
        # this is how you get values out of a tuple
        (lon, lat) = lon_lat
        
        # add them to our list
        latlons.append((lat, lon)) 
    
    # npts doesn't include start/end points, so prepend/append them
    latlons.insert(0, (startlat, startlon))
    latlons.append((endlat, endlon))
    
    return latlons

# %%
# any time we write a function, we should test that it works
p = getGreatCirclePoints(38.034, -84.500, 33.636700, -84.428101) 
p
# Out:
# [(38.034, -84.5),
#  (37.864933929949096, -84.49708149511396),
#  (37.695862920583586, -84.49417629534568),
#  (37.52678697986378, -84.49128425988357),
#  (37.35770611591111, -84.48840524964173),
#  (37.18862033700805, -84.48553912723197),
#  (37.019529651598035, -84.48268575693639),
#  (36.85043406828536, -84.47984500468044),
#  (36.68133359583508, -84.4770167380065),
#  (36.51222824317288, -84.474200826048),
#  (36.343118019385024, -84.47139713950395),
#  (36.17400293371815, -84.46860555061399),
#  (36.00488299557918, -84.46582593313389),
#  (35.83575821453518, -84.46305816231151),
#  (35.66662860031317, -84.46030211486323),
#  (35.49749416279997, -84.45755766895067),
#  (35.328354912042094, -84.45482470415813),
#  (35.15921085824549, -84.45210310147009),
#  (34.99006201177538, -84.44939274324938),
#  (34.82090838315612, -84.44669351321562),
#  (34.65174998307092, -84.44400529642411),
#  (34.48258682236167, -84.44132797924507),
#  (34.3134189120287, -84.43866144934323),
#  (34.14424626323062, -84.43600559565783),
#  (33.975068887284, -84.43336030838299),
#  (33.805886795663184, -84.4307254789483),
#  (33.6367, -84.428101)]

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# define the map in the same way, but use great circles for the lines

# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # PolyLine will accept a whole list of tuples, not just two
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']       
        
        gc_points = getGreatCirclePoints(row["latitude_source"], 
                                         row["longitude_source"], 
                                         row["latitude_dest"], 
                                         row["longitude_dest"])
        
        line = folium.PolyLine(gc_points, weight=2, popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# save it to its own file
lex_air.save("lex_air.html")

# %% [markdown]
# ### Your turn
#
# The above map shows everywhere you can get to from Lexington on a direct flight.  Your job is to:
#
# 1. Make a map of all the possible destinations with one transfer.
# 2. Make a map of all the possible desitnations with two transfers.
#
# Make the maps look nice!  Use color coding, vary the size of the features, or be selective about what you display in order to communicate the information effectively.
#
# Bonus: This is the air travel version of the Kevin Bacon game (https://oracleofbacon.org/).  What is the number N, such that you can reach every airport in the world with N or fewer transfers?
#
# Extra Bonus: Use this very important piece of knowledge to impress your friends at parties!

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(location=[38.034,-84.500],zoom_start=4)

# %%
#one transfer
lex_routes = routes[(routes['source']=="LEX")]
lex_routes = pd.merge(lex_routes, routes, left_on = 'dest_id', right_on='source_id',how='left')
lex_routes = pd.merge(lex_routes, airports, left_on='source_id_x', right_on='id', how='left')
lex_routes = pd.merge(lex_routes, airports, left_on='dest_id_y', right_on='id', how='left',suffixes=['_source','_dest'])
lex_routes=lex_routes.dropna(subset=['id_dest'])
lex_routes=lex_routes[lex_routes.dest_y != 'LEX']
lex_routes=lex_routes[lex_routes.name_dest != 'South Pole Station']
lex_routes=lex_routes.drop_duplicates(subset=['source_x','dest_y'])
lex_routes
# Out:
#      airline_x  airline_id_x source_x  source_id_x dest_x  dest_id_x  \
# 0           9E        3976.0      LEX       4017.0    ATL     3682.0
# 1           9E        3976.0      LEX       4017.0    ATL     3682.0
# 2           9E        3976.0      LEX       4017.0    ATL     3682.0
# 3           9E        3976.0      LEX       4017.0    ATL     3682.0
# 4           9E        3976.0      LEX       4017.0    ATL     3682.0
# 5           9E        3976.0      LEX       4017.0    ATL     3682.0
# 6           9E        3976.0      LEX       4017.0    ATL     3682.0
# 7           9E        3976.0      LEX       4017.0    ATL     3682.0
# 8           9E        3976.0      LEX       4017.0    ATL     3682.0
# 9           9E        3976.0      LEX       4017.0    ATL     3682.0
# 10          9E        3976.0      LEX       4017.0    ATL     3682.0
# 11          9E        3976.0      LEX       4017.0    ATL     3682.0
# 12          9E        3976.0      LEX       4017.0    ATL     3682.0
# 13          9E        3976.0      LEX       4017.0    ATL     3682.0
# 14          9E        3976.0      LEX       4017.0    ATL     3682.0
# 15          9E        3976.0      LEX       4017.0    ATL     3682.0
# 17          9E        3976.0      LEX       4017.0    ATL     3682.0
# 18          9E        3976.0      LEX       4017.0    ATL     3682.0
# 19          9E        3976.0      LEX       4017.0    ATL     3682.0
# 20          9E        3976.0      LEX       4017.0    ATL     3682.0
# 21          9E        3976.0      LEX       4017.0    ATL     3682.0
# 22          9E        3976.0      LEX       4017.0    ATL     3682.0
# 23          9E        3976.0      LEX       4017.0    ATL     3682.0
# 24          9E        3976.0      LEX       4017.0    ATL     3682.0
# 25          9E        3976.0      LEX       4017.0    ATL     3682.0
# 26          9E        3976.0      LEX       4017.0    ATL     3682.0
# 27          9E        3976.0      LEX       4017.0    ATL     3682.0
# 28          9E        3976.0      LEX       4017.0    ATL     3682.0
# 29          9E        3976.0      LEX       4017.0    ATL     3682.0
# 30          9E        3976.0      LEX       4017.0    ATL     3682.0
# ...        ...           ...      ...          ...    ...        ...
# 4962        G4          35.0      LEX       4017.0    FLL     3533.0
# 4980        G4          35.0      LEX       4017.0    FLL     3533.0
# 4983        G4          35.0      LEX       4017.0    FLL     3533.0
# 4985        G4          35.0      LEX       4017.0    FLL     3533.0
# 5058        G4          35.0      LEX       4017.0    PGD     7056.0
# 5064        G4          35.0      LEX       4017.0    PGD     7056.0
# 5080        G4          35.0      LEX       4017.0    PIE     3617.0
# 5096        G4          35.0      LEX       4017.0    SFB     4167.0
# 5103        G4          35.0      LEX       4017.0    SFB     4167.0
# 5108        G4          35.0      LEX       4017.0    SFB     4167.0
# 5119        G4          35.0      LEX       4017.0    SFB     4167.0
# 5129        G4          35.0      LEX       4017.0    SFB     4167.0
# 5132        G4          35.0      LEX       4017.0    SFB     4167.0
# 6114        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6124        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6128        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6136        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6153        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6166        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6185        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6186        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6188        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6216        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6227        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6265        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6269        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6278        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6280        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6287        UA        5209.0      LEX       4017.0    IAH     3550.0
# 6288        UA        5209.0      LEX       4017.0    IAH     3550.0
#
#      codeshare_x  stops_x equipment_x airline_y     ...       iata_dest  \
# 0            NaN        0         CRJ        3M     ...             LWB
# 1            NaN        0         CRJ        3M     ...             MCN
# 2            NaN        0         CRJ        3M     ...             MEI
# 3            NaN        0         CRJ        3M     ...             MSL
# 4            NaN        0         CRJ        3M     ...             PIB
# 5            NaN        0         CRJ        3M     ...             TUP
# 6            NaN        0         CRJ        9E     ...             AZO
# 7            NaN        0         CRJ        9E     ...             CHA
# 8            NaN        0         CRJ        9E     ...             CID
# 9            NaN        0         CRJ        9E     ...             CRW
# 10           NaN        0         CRJ        9E     ...             CVG
# 11           NaN        0         CRJ        9E     ...             EVV
# 12           NaN        0         CRJ        9E     ...             FWA
# 13           NaN        0         CRJ        9E     ...             GSO
# 14           NaN        0         CRJ        9E     ...             GSP
# 15           NaN        0         CRJ        9E     ...             LAN
# 17           NaN        0         CRJ        9E     ...             MBS
# 18           NaN        0         CRJ        9E     ...             MSP
# 19           NaN        0         CRJ        9E     ...             ROA
# 20           NaN        0         CRJ        9E     ...             SYR
# 21           NaN        0         CRJ        9E     ...             TYS
# 22           NaN        0         CRJ        9E     ...             XNA
# 23           NaN        0         CRJ        AA     ...             CLT
# 24           NaN        0         CRJ        AA     ...             DFW
# 25           NaN        0         CRJ        AA     ...             LHR
# 26           NaN        0         CRJ        AA     ...             MIA
# 27           NaN        0         CRJ        AA     ...             ORD
# 28           NaN        0         CRJ        AA     ...             PHL
# 29           NaN        0         CRJ        AA     ...             PHX
# 30           NaN        0         CRJ        AC     ...             DEN
# ...          ...      ...         ...       ...     ...             ...
# 4962         NaN        0         M80        NK     ...             LBE
# 4980         NaN        0         M80        NK     ...             STI
# 4983         NaN        0         M80        NK     ...             TLC
# 4985         NaN        0         M80        NK     ...             ZSA
# 5058         NaN        0         M80        G4     ...             RFD
# 5064         NaN        0         M80        G4     ...             YNG
# 5080         NaN        0         320        G4     ...             LCK
# 5096         NaN        0     M80 320        FI     ...             KEF
# 5103         NaN        0     M80 320        G4     ...             BLV
# 5108         NaN        0     M80 320        G4     ...             CKB
# 5119         NaN        0     M80 320        G4     ...             HGR
# 5129         NaN        0     M80 320        G4     ...             OWB
# 5132         NaN        0     M80 320        G4     ...             PSM
# 6114           Y        0         ERJ        LW     ...             VCT
# 6124           Y        0         ERJ        SQ     ...             DME
# 6128           Y        0         ERJ        UA     ...             ACA
# 6136           Y        0         ERJ        UA     ...             BFL
# 6153           Y        0         ERJ        UA     ...             CME
# 6166           Y        0         ERJ        UA     ...             DGO
# 6185           Y        0         ERJ        UA     ...             HOB
# 6186           Y        0         ERJ        UA     ...             HRL
# 6188           Y        0         ERJ        UA     ...             HUX
# 6216           Y        0         ERJ        UA     ...             MID
# 6227           Y        0         ERJ        UA     ...             OAX
# 6265           Y        0         ERJ        UA     ...             SLW
# 6269           Y        0         ERJ        UA     ...             TAM
# 6278           Y        0         ERJ        UA     ...             VER
# 6280           Y        0         ERJ        UA     ...             VSA
# 6287           Y        0         ERJ        UA     ...             ZIH
# 6288           Y        0         ERJ        UA     ...             ZLO
#
#      icao_dest  latitude_dest longitude_dest  altitude_dest timezone_dest  \
# 0         KLWB      37.858299     -80.399498         2302.0          -5.0
# 1         KMCN      32.692799     -83.649200          354.0          -5.0
# 2         KMEI      32.332600     -88.751900          297.0          -6.0
# 3         KMSL      34.745300     -87.610199          551.0          -6.0
# 4         KPIB      31.467100     -89.337097          298.0          -6.0
# 5         KTUP      34.268101     -88.769897          346.0          -6.0
# 6         KAZO      42.234901     -85.552101          874.0          -5.0
# 7         KCHA      35.035301     -85.203796          683.0          -5.0
# 8         KCID      41.884701     -91.710800          869.0          -6.0
# 9         KCRW      38.373100     -81.593201          981.0          -5.0
# 10        KCVG      39.048801     -84.667801          896.0          -5.0
# 11        KEVV      38.036999     -87.532402          418.0          -6.0
# 12        KFWA      40.978500     -85.195099          814.0          -5.0
# 13        KGSO      36.097801     -79.937302          925.0          -5.0
# 14        KGSP      34.895699     -82.218903          964.0          -5.0
# 15        KLAN      42.778702     -84.587402          861.0          -5.0
# 17        KMBS      43.532902     -84.079597          668.0          -5.0
# 18        KMSP      44.882000     -93.221802          841.0          -6.0
# 19        KROA      37.325500     -79.975403         1175.0          -5.0
# 20        KSYR      43.111198     -76.106300          421.0          -5.0
# 21        KTYS      35.811001     -83.994003          981.0          -5.0
# 22        KXNA      36.281898     -94.306801         1287.0          -6.0
# 23        KCLT      35.214001     -80.943100          748.0          -5.0
# 24        KDFW      32.896801     -97.038002          607.0          -6.0
# 25        EGLL      51.470600      -0.461941           83.0           0.0
# 26        KMIA      25.793200     -80.290604            8.0          -5.0
# 27        KORD      41.978600     -87.904800          672.0          -6.0
# 28        KPHL      39.871899     -75.241096           36.0          -5.0
# 29        KPHX      33.434299    -112.012001         1135.0          -7.0
# 30        KDEN      39.861698    -104.672997         5431.0          -7.0
# ...        ...            ...            ...            ...           ...
# 4962      KLBE      40.275902     -79.404800         1199.0          -5.0
# 4980      MDST      19.406099     -70.604698          565.0          -4.0
# 4983      MMTO      19.337099     -99.566002         8466.0          -6.0
# 4985      MYSM      24.063299     -74.524002           24.0          -5.0
# 5058      KRFD      42.195400     -89.097198          742.0          -6.0
# 5064      KYNG      41.260700     -80.679100         1192.0          -5.0
# 5080      KLCK      39.813801     -82.927803          744.0          -5.0
# 5096      BIKF      63.985001     -22.605600          171.0           0.0
# 5103      KBLV      38.545200     -89.835197          459.0          -6.0
# 5108      KCKB      39.296600     -80.228104         1217.0          -5.0
# 5119      KHGR      39.707901     -77.729500          703.0          -5.0
# 5129      KOWB      37.740101     -87.166801          407.0          -6.0
# 5132      KPSM      43.077900     -70.823303          100.0          -5.0
# 6114      KVCT      28.852600     -96.918503          115.0          -6.0
# 6124      UUDD      55.408798      37.906300          588.0           3.0
# 6128      MMAA      16.757099     -99.753998           16.0          -6.0
# 6136      KBFL      35.433601    -119.056999          510.0          -8.0
# 6153      MMCE      18.653700     -91.799004           10.0          -6.0
# 6166      MMDO      24.124201    -104.528000         6104.0          -6.0
# 6185      KHOB      32.687500    -103.217003         3661.0          -7.0
# 6186      KHRL      26.228500     -97.654404           36.0          -6.0
# 6188      MMBT      15.775300     -96.262604          464.0          -6.0
# 6216      MMMD      20.937000     -89.657700           38.0          -6.0
# 6227      MMOX      16.999901     -96.726601         4989.0          -6.0
# 6265      MMIO      25.549500    -100.929001         4778.0          -6.0
# 6269      MMTM      22.296400     -97.865898           80.0          -6.0
# 6278      MMVR      19.145901     -96.187302           90.0          -6.0
# 6280      MMVA      17.997000     -92.817398           46.0          -6.0
# 6287      MMZH      17.601601    -101.460999           26.0          -6.0
# 6288      MMZO      19.144800    -104.558998           30.0          -6.0
#
#       dst_dest                tz_dest  type_dest  source_dest
# 0            U       America/New_York    airport  OurAirports
# 1            A       America/New_York    airport  OurAirports
# 2            A        America/Chicago    airport  OurAirports
# 3            A        America/Chicago    airport  OurAirports
# 4            A        America/Chicago    airport  OurAirports
# 5            A        America/Chicago    airport  OurAirports
# 6            A       America/New_York    airport  OurAirports
# 7            A       America/New_York    airport  OurAirports
# 8            A        America/Chicago    airport  OurAirports
# 9            A       America/New_York    airport  OurAirports
# 10           A       America/New_York    airport  OurAirports
# 11           A        America/Chicago    airport  OurAirports
# 12           A       America/New_York    airport  OurAirports
# 13           A       America/New_York    airport  OurAirports
# 14           A       America/New_York    airport  OurAirports
# 15           A       America/New_York    airport  OurAirports
# 17           A       America/New_York    airport  OurAirports
# 18           A        America/Chicago    airport  OurAirports
# 19           A       America/New_York    airport  OurAirports
# 20           A       America/New_York    airport  OurAirports
# 21           A       America/New_York    airport  OurAirports
# 22           A        America/Chicago    airport  OurAirports
# 23           A       America/New_York    airport  OurAirports
# 24           A        America/Chicago    airport  OurAirports
# 25           E          Europe/London    airport  OurAirports
# 26           A       America/New_York    airport  OurAirports
# 27           A        America/Chicago    airport  OurAirports
# 28           A       America/New_York    airport  OurAirports
# 29           N        America/Phoenix    airport  OurAirports
# 30           A         America/Denver    airport  OurAirports
# ...        ...                    ...        ...          ...
# 4962         A       America/New_York    airport  OurAirports
# 4980         U  America/Santo_Domingo    airport  OurAirports
# 4983         S    America/Mexico_City    airport  OurAirports
# 4985         U         America/Nassau    airport  OurAirports
# 5058         A        America/Chicago    airport  OurAirports
# 5064         A       America/New_York    airport  OurAirports
# 5080         A       America/New_York    airport  OurAirports
# 5096         N     Atlantic/Reykjavik    airport  OurAirports
# 5103         A        America/Chicago    airport  OurAirports
# 5108         A       America/New_York    airport  OurAirports
# 5119         A       America/New_York    airport  OurAirports
# 5129         A        America/Chicago    airport  OurAirports
# 5132         A       America/New_York    airport  OurAirports
# 6114         A        America/Chicago    airport  OurAirports
# 6124         N          Europe/Moscow    airport  OurAirports
# 6128         S    America/Mexico_City    airport  OurAirports
# 6136         A    America/Los_Angeles    airport  OurAirports
# 6153         S    America/Mexico_City    airport  OurAirports
# 6166         S    America/Mexico_City    airport  OurAirports
# 6185         A         America/Denver    airport  OurAirports
# 6186         A        America/Chicago    airport  OurAirports
# 6188         S    America/Mexico_City    airport  OurAirports
# 6216         S    America/Mexico_City    airport  OurAirports
# 6227         S    America/Mexico_City    airport  OurAirports
# 6265         S    America/Mexico_City    airport  OurAirports
# 6269         S    America/Mexico_City    airport  OurAirports
# 6278         S    America/Mexico_City    airport  OurAirports
# 6280         S    America/Mexico_City    airport  OurAirports
# 6287         S    America/Mexico_City    airport  OurAirports
# 6288         S    America/Mexico_City    airport  OurAirports
#
# [397 rows x 46 columns]

# %%
df=lex_routes['country_dest'].unique()

for members in df:
    lex_route = lex_routes[lex_routes['country_dest']==members]
    h = folium.FeatureGroup(members)
    # Define some empty sets
    airport_set = set()
    route_set = set()
    

    # Make sure we don't add duplicates, especially for the origins
    for index, row in lex_route.iterrows():
        if row['source_x'] not in airport_set: 
            popup_string = row['city_source'] + '(' + row['source_x'] + ')'
            marker1 = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=2, popup=folium.Popup(popup_string, parse_html=True)).add_to(h)
            
            airport_set.add(row['source_x'])
        
        if row['dest_y'] not in airport_set: 
            popup_string = row['city_dest'] + '(' + row['dest_y'] + ')'
            marker2 = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=2, popup=folium.Popup(popup_string, parse_html=True)).add_to(h)
            
            airport_set.add(row['dest_y'])
    
        # PolyLine will accept a whole list of tuples, not just two

        if (row['source_x'],row['dest_y']) not in route_set:            
            popup_string = row['source_x'] + '-' + row['dest_y'] + ' (' + 'via ' + row['dest_x'] + ')'  
            
            gc_points = getGreatCirclePoints(row["latitude_source"], 
                                         row["longitude_source"], 
                                         row["latitude_dest"], 
                                         row["longitude_dest"])
            
            line = folium.PolyLine(gc_points, weight=1, popup=folium.Popup(popup_string, parse_html=True)).add_to(h)
            
            route_set.add((row['source_x'],row['dest_y']))
        
    h.add_to(lex_air)

lex_air.add_child(folium.LayerControl())
lex_air.save('one_trans.html')

# %%
#two transfers
lex_routes = routes[(routes['source']=="LEX")]
lex_routes = pd.merge(lex_routes, routes, left_on = 'dest_id', right_on='source_id',how='left')
lex_routes = pd.merge(lex_routes, routes, left_on = 'dest_id_y', right_on='source_id',how='left')
lex_routes = pd.merge(lex_routes, airports, left_on='source_id_x', right_on='id', how='left',suffixes=['_source','_dest'])
lex_routes = lex_routes.drop(['source_y'], axis=1)
lex_routes = pd.merge(lex_routes, airports, left_on='dest_id', right_on='id', how='left',suffixes=['_source','_dest'])

#one of the dest shows NaN, so it was dropped
lex_routes=lex_routes.dropna(subset=['id_dest'])

#some dest had LEX in it so those were excluded from routes
lex_routes=lex_routes[lex_routes.dest != 'LEX']

#some dest had duplicates so those were excluded from routes keeping the first one
lex_routes=lex_routes.drop_duplicates(subset=['source_x','dest'])
lex_routes
# Out:
#        airline_x  airline_id_x source_x  source_id_x dest_x  dest_id_x  \
# 0             9E        3976.0      LEX       4017.0    ATL     3682.0
# 1             9E        3976.0      LEX       4017.0    ATL     3682.0
# 3             9E        3976.0      LEX       4017.0    ATL     3682.0
# 8             9E        3976.0      LEX       4017.0    ATL     3682.0
# 10            9E        3976.0      LEX       4017.0    ATL     3682.0
# 12            9E        3976.0      LEX       4017.0    ATL     3682.0
# 13            9E        3976.0      LEX       4017.0    ATL     3682.0
# 16            9E        3976.0      LEX       4017.0    ATL     3682.0
# 17            9E        3976.0      LEX       4017.0    ATL     3682.0
# 18            9E        3976.0      LEX       4017.0    ATL     3682.0
# 24            9E        3976.0      LEX       4017.0    ATL     3682.0
# 25            9E        3976.0      LEX       4017.0    ATL     3682.0
# 37            9E        3976.0      LEX       4017.0    ATL     3682.0
# 38            9E        3976.0      LEX       4017.0    ATL     3682.0
# 39            9E        3976.0      LEX       4017.0    ATL     3682.0
# 40            9E        3976.0      LEX       4017.0    ATL     3682.0
# 53            9E        3976.0      LEX       4017.0    ATL     3682.0
# 58            9E        3976.0      LEX       4017.0    ATL     3682.0
# 59            9E        3976.0      LEX       4017.0    ATL     3682.0
# 61            9E        3976.0      LEX       4017.0    ATL     3682.0
# 62            9E        3976.0      LEX       4017.0    ATL     3682.0
# 64            9E        3976.0      LEX       4017.0    ATL     3682.0
# 66            9E        3976.0      LEX       4017.0    ATL     3682.0
# 69            9E        3976.0      LEX       4017.0    ATL     3682.0
# 70            9E        3976.0      LEX       4017.0    ATL     3682.0
# 71            9E        3976.0      LEX       4017.0    ATL     3682.0
# 72            9E        3976.0      LEX       4017.0    ATL     3682.0
# 80            9E        3976.0      LEX       4017.0    ATL     3682.0
# 81            9E        3976.0      LEX       4017.0    ATL     3682.0
# 82            9E        3976.0      LEX       4017.0    ATL     3682.0
# ...          ...           ...      ...          ...    ...        ...
# 866157        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866158        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866159        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866161        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866165        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866168        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866169        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866172        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866173        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866175        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866179        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866181        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866184        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866210        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866220        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866221        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866228        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866244        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866249        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866251        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866256        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866259        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866262        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866264        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866277        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866280        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866305        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866315        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866318        UA        5209.0      LEX       4017.0    IAH     3550.0
# 866329        UA        5209.0      LEX       4017.0    IAH     3550.0
#
#        codeshare_x  stops_x equipment_x airline_y     ...       iata_dest  \
# 0              NaN        0         CRJ        3M     ...             ATL
# 1              NaN        0         CRJ        3M     ...             IAD
# 3              NaN        0         CRJ        3M     ...             MCO
# 8              NaN        0         CRJ        3M     ...             GLH
# 10             NaN        0         CRJ        9E     ...             ORD
# 12             NaN        0         CRJ        9E     ...             DTW
# 13             NaN        0         CRJ        9E     ...             MSP
# 16             NaN        0         CRJ        9E     ...             CLT
# 17             NaN        0         CRJ        9E     ...             DCA
# 18             NaN        0         CRJ        9E     ...             DFW
# 24             NaN        0         CRJ        9E     ...             PIE
# 25             NaN        0         CRJ        9E     ...             SFB
# 37             NaN        0         CRJ        9E     ...             DEN
# 38             NaN        0         CRJ        9E     ...             AZA
# 39             NaN        0         CRJ        9E     ...             LAS
# 40             NaN        0         CRJ        9E     ...             PGD
# 53             NaN        0         CRJ        9E     ...             MYR
# 58             NaN        0         CRJ        9E     ...             JFK
# 59             NaN        0         CRJ        9E     ...             MIA
# 61             NaN        0         CRJ        9E     ...             PHL
# 62             NaN        0         CRJ        9E     ...             YYZ
# 64             NaN        0         CRJ        9E     ...             CDG
# 66             NaN        0         CRJ        9E     ...             CUN
# 69             NaN        0         CRJ        9E     ...             BDL
# 70             NaN        0         CRJ        9E     ...             BNA
# 71             NaN        0         CRJ        9E     ...             BOS
# 72             NaN        0         CRJ        9E     ...             BWI
# 80             NaN        0         CRJ        9E     ...             EWR
# 81             NaN        0         CRJ        9E     ...             FLL
# 82             NaN        0         CRJ        9E     ...             GRR
# ...            ...      ...         ...       ...     ...             ...
# 866157           Y        0         ERJ        SQ     ...             NSK
# 866158           Y        0         ERJ        SQ     ...             NUX
# 866159           Y        0         ERJ        SQ     ...             NYM
# 866161           Y        0         ERJ        SQ     ...             OGZ
# 866165           Y        0         ERJ        SQ     ...             PEE
# 866168           Y        0         ERJ        SQ     ...             PWQ
# 866169           Y        0         ERJ        SQ     ...             RGK
# 866172           Y        0         ERJ        SQ     ...             SGC
# 866173           Y        0         ERJ        SQ     ...             SIP
# 866175           Y        0         ERJ        SQ     ...             STW
# 866179           Y        0         ERJ        SQ     ...             TJM
# 866181           Y        0         ERJ        SQ     ...             TOF
# 866184           Y        0         ERJ        SQ     ...             UKK
# 866210           Y        0         ERJ        SQ     ...             GBB
# 866220           Y        0         ERJ        SQ     ...             LLK
# 866221           Y        0         ERJ        SQ     ...             LWN
# 866228           Y        0         ERJ        SQ     ...             RMI
# 866244           Y        0         ERJ        SQ     ...             BQS
# 866249           Y        0         ERJ        SQ     ...             DYR
# 866251           Y        0         ERJ        SQ     ...             GDX
# 866256           Y        0         ERJ        SQ     ...             HMA
# 866259           Y        0         ERJ        SQ     ...             IEV
# 866262           Y        0         ERJ        SQ     ...             KGF
# 866264           Y        0         ERJ        SQ     ...             KOV
# 866277           Y        0         ERJ        SQ     ...             PED
# 866280           Y        0         ERJ        SQ     ...             PKC
# 866305           Y        0         ERJ        SQ     ...             CXR
# 866315           Y        0         ERJ        SQ     ...             NOJ
# 866318           Y        0         ERJ        SQ     ...             SLY
# 866329           Y        0         ERJ        SQ     ...             UKS
#
#         icao_dest latitude_dest  longitude_dest altitude_dest  timezone_dest  \
# 0            KATL     33.636700      -84.428101        1026.0           -5.0
# 1            KIAD     38.944500      -77.455803         312.0           -5.0
# 3            KMCO     28.429399      -81.308998          96.0           -5.0
# 8            KGLH     33.482899      -90.985603         131.0           -6.0
# 10           KORD     41.978600      -87.904800         672.0           -6.0
# 12           KDTW     42.212399      -83.353401         645.0           -5.0
# 13           KMSP     44.882000      -93.221802         841.0           -6.0
# 16           KCLT     35.214001      -80.943100         748.0           -5.0
# 17           KDCA     38.852100      -77.037697          15.0           -5.0
# 18           KDFW     32.896801      -97.038002         607.0           -6.0
# 24           KPIE     27.910200      -82.687401          11.0           -5.0
# 25           KSFB     28.777599      -81.237503          55.0           -5.0
# 37           KDEN     39.861698     -104.672997        5431.0           -7.0
# 38           KIWA     33.307800     -111.654999        1382.0           -7.0
# 39           KLAS     36.080101     -115.152000        2181.0           -8.0
# 40           KPGD     26.920200      -81.990501          26.0           -5.0
# 53           KMYR     33.679699      -78.928299          25.0           -5.0
# 58           KJFK     40.639801      -73.778900          13.0           -5.0
# 59           KMIA     25.793200      -80.290604           8.0           -5.0
# 61           KPHL     39.871899      -75.241096          36.0           -5.0
# 62           CYYZ     43.677200      -79.630600         569.0           -5.0
# 64           LFPG     49.012798        2.550000         392.0            1.0
# 66           MMUN     21.036501      -86.877098          22.0           -5.0
# 69           KBDL     41.938900      -72.683197         173.0           -5.0
# 70           KBNA     36.124500      -86.678200         599.0           -6.0
# 71           KBOS     42.364300      -71.005203          20.0           -5.0
# 72           KBWI     39.175400      -76.668297         146.0           -5.0
# 80           KEWR     40.692501      -74.168701          18.0           -5.0
# 81           KFLL     26.072599      -80.152702           9.0           -5.0
# 82           KGRR     42.880798      -85.522797         794.0           -5.0
# ...           ...           ...             ...           ...            ...
# 866157       UOOO     69.311096       87.332199         574.0            7.0
# 866158       USMU     66.069397       76.520302         210.0            5.0
# 866159       USMM     65.480904       72.698898          49.0            5.0
# 866161       URMO     43.205101       44.606602        1673.0            3.0
# 866165       USPP     57.914501       56.021198         404.0            5.0
# 866168       UASP     52.195000       77.073898         410.0            6.0
# 866169       UNBG     51.966702       85.833298         965.0            7.0
# 866172       USRR     61.343700       73.401802         200.0            5.0
# 866173       UKFF     45.052200       33.975101         639.0            3.0
# 866175       URMT     45.109200       42.112801        1486.0            3.0
# 866179       USTR     57.189602       65.324303         378.0            5.0
# 866181       UNTT     56.380299       85.208298         597.0            7.0
# 866184       UASK     50.036598       82.494202         939.0            6.0
# 866210       UBBQ     40.826667       47.712500         935.0            4.0
# 866220       UBBL     38.746399       48.818001          30.0            4.0
# 866221       UDSG     40.750401       43.859299        5000.0            4.0
# 866228       LIPR     44.020302       12.611700          40.0            1.0
# 866244       UHBB     50.425400      127.412003         638.0            9.0
# 866249       UHMA     64.734901      177.740997         194.0           12.0
# 866251       UHMM     59.910999      150.720001         574.0           11.0
# 866256       USHH     61.028500       69.086098          76.0            5.0
# 866259       UKKK     50.401940       30.451940         587.0            2.0
# 866262       UAKK     49.670799       73.334396        1765.0            6.0
# 866264       UACK     53.329102       69.594597         900.0            6.0
# 866277       LKPD     50.013401       15.738600         741.0            1.0
# 866280       UHPP     53.167900      158.453995         131.0           12.0
# 866305       VVCR     11.998200      109.219002          40.0            7.0
# 866315       USRO     63.183300       75.269997         446.0            5.0
# 866318       USDD     66.590797       66.611000         218.0            5.0
# 866329       UKFB     44.688999       33.570999         344.0            3.0
#
#        dst_dest              tz_dest  type_dest       source
# 0             A     America/New_York    airport  OurAirports
# 1             A     America/New_York    airport  OurAirports
# 3             A     America/New_York    airport  OurAirports
# 8             A      America/Chicago    airport  OurAirports
# 10            A      America/Chicago    airport  OurAirports
# 12            A     America/New_York    airport  OurAirports
# 13            A      America/Chicago    airport  OurAirports
# 16            A     America/New_York    airport  OurAirports
# 17            A     America/New_York    airport  OurAirports
# 18            A      America/Chicago    airport  OurAirports
# 24            A     America/New_York    airport  OurAirports
# 25            A     America/New_York    airport  OurAirports
# 37            A       America/Denver    airport  OurAirports
# 38            N      America/Phoenix    airport  OurAirports
# 39            A  America/Los_Angeles    airport  OurAirports
# 40            A     America/New_York    airport  OurAirports
# 53            A     America/New_York    airport  OurAirports
# 58            A     America/New_York    airport  OurAirports
# 59            A     America/New_York    airport  OurAirports
# 61            A     America/New_York    airport  OurAirports
# 62            A      America/Toronto    airport  OurAirports
# 64            E         Europe/Paris    airport  OurAirports
# 66            S       America/Cancun    airport  OurAirports
# 69            A     America/New_York    airport  OurAirports
# 70            A      America/Chicago    airport  OurAirports
# 71            A     America/New_York    airport  OurAirports
# 72            A     America/New_York    airport  OurAirports
# 80            A     America/New_York    airport  OurAirports
# 81            A     America/New_York    airport  OurAirports
# 82            A     America/New_York    airport  OurAirports
# ...         ...                  ...        ...          ...
# 866157        N     Asia/Krasnoyarsk    airport  OurAirports
# 866158        N   Asia/Yekaterinburg    airport  OurAirports
# 866159        N   Asia/Yekaterinburg    airport  OurAirports
# 866161        N        Europe/Moscow    airport  OurAirports
# 866165        N   Asia/Yekaterinburg    airport  OurAirports
# 866168        U       Asia/Qyzylorda    airport  OurAirports
# 866169        N     Asia/Krasnoyarsk    airport  OurAirports
# 866172        N   Asia/Yekaterinburg    airport  OurAirports
# 866173        E    Europe/Simferopol    airport  OurAirports
# 866175        N        Europe/Moscow    airport  OurAirports
# 866179        N   Asia/Yekaterinburg    airport  OurAirports
# 866181        N     Asia/Krasnoyarsk    airport  OurAirports
# 866184        U       Asia/Qyzylorda    airport  OurAirports
# 866210        E            Asia/Baku    airport  OurAirports
# 866220        U            Asia/Baku    airport  OurAirports
# 866221        E         Asia/Yerevan    airport  OurAirports
# 866228        E          Europe/Rome    airport  OurAirports
# 866244        N         Asia/Yakutsk    airport  OurAirports
# 866249        N          Asia/Anadyr    airport  OurAirports
# 866251        N   Asia/Srednekolymsk    airport  OurAirports
# 866256        N   Asia/Yekaterinburg    airport  OurAirports
# 866259        E          Europe/Kiev    airport  OurAirports
# 866262        U       Asia/Qyzylorda    airport  OurAirports
# 866264        U       Asia/Qyzylorda    airport  OurAirports
# 866277        E        Europe/Prague    airport  OurAirports
# 866280        N          Asia/Anadyr    airport  OurAirports
# 866305        U          Asia/Saigon    airport  OurAirports
# 866315        N   Asia/Yekaterinburg    airport  OurAirports
# 866318        N   Asia/Yekaterinburg    airport  OurAirports
# 866329        U    Europe/Simferopol    airport  OurAirports
#
# [1807 rows x 54 columns]

# %%
# create a basic map, centered on Lexington
lex_map = folium.Map(location=[38.034,-84.500],zoom_start=4)

# %%
df1=lex_routes['country_dest'].unique()

for members in df1:
    lex_route = lex_routes[lex_routes['country_dest']==members]
    h = folium.FeatureGroup(members)
    # Define some empty sets
    airport_set = set()
    route_set = set()
    

    # Make sure we don't add duplicates, especially for the origins
    for index, row in lex_route.iterrows():
        if row['source_x'] not in airport_set: 
            popup_string = row['city_source'] + '(' + row['source_x'] + ')'
            marker1 = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='green',
                                     fill_color='green', 
                                     radius=2, popup=folium.Popup(popup_string, parse_html=True)).add_to(h)
            
            airport_set.add(row['source_x'])
        
        if row['dest'] not in airport_set: 
            popup_string = row['city_dest'] + '(' + row['dest'] + ')'
            marker2 = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='green',
                                     fill_color='green', 
                                     radius=2, popup=folium.Popup(popup_string, parse_html=True)).add_to(h)
            
            airport_set.add(row['dest'])
    
        # PolyLine will accept a whole list of tuples, not just two

        if (row['source_x'],row['dest']) not in route_set:            
            popup_string = row['source_x'] + '-' + row['dest'] + ' (' + 'via ' + row['dest_x'] + " & " + row['dest_y'] +')'  
            
            gc_points = getGreatCirclePoints(row["latitude_source"], 
                                         row["longitude_source"], 
                                         row["latitude_dest"], 
                                         row["longitude_dest"])
            
            line = folium.PolyLine(gc_points, weight=1, color='green', popup=folium.Popup(popup_string, parse_html=True)).add_to(h)
            
            route_set.add((row['source_x'],row['dest']))
        
    h.add_to(lex_map)

lex_map.add_child(folium.LayerControl())
lex_map.save('two_trans.html')
