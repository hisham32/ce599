# %% [markdown]
# # Data Wrangling in Pandas
#
# This session draws primarily on Chapter 7 in Python for Data Analysis.  It covers methods that are used heavily in 'data wrangling', which refers to the data manipulation that is often needed to transform raw data into a form that is useful for analysis.  We'll stick to the data and examples used in the book for most of this session, since the examples are clearer on the tiny datasets.  After that we will work through some of these methods again using real data.
#
# Key methods covered include:
#
# * Merging and Concatenating
# * Reshaping data
# * Data transformations
# * Categorization
# * Detecting and Filtering Outliers
# * Creating Dummy Variables

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Merging
#
# Merging two datasets is a very common operation in preparing data for analysis.  It generally means adding columns from one table to colums from another, where the value of some key, or merge field, matches.
#
# Let's begin by creating two simple DataFrames to be merged.

# %%
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],'data1': range(7)})
df2 = pd.DataFrame({'key': ['a', 'b', 'd'],'data2': range(3)})
print(df1)
print(df2)
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2

# %% [markdown]
# Here is a many to one merge.  The join field is implicit, based on what columns it finds in common between the two dataframes. Note that they share some values of the key field (a, b), but do not share key values c and d.  What do you expect to happen when we merge them? The result contains the values from both inputs where they both have a value of the merge field, which is 'key' in this example.  The default behavior is that the key value has to be in both inputs to be kept.  In set terms it would be an intersection of the two sets.

# %%
pd.merge(df1,df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %% [markdown]
# Here is the same merge, but making the join field explicit.

# %%
pd.merge(df1,df2, on='key')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
#what if there are more than one value of key in both dataframes? This is a many-to-many merge.
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],'data1': range(7)})
df3 = pd.DataFrame({'key': ['a', 'b', 'b', 'd'],'data2': range(4)})
print(df1)
print(df3)
pd.merge(df1,df3, on='key')
#This produces a cartesian product of the number of occurrences of each key value in both dataframes:
# (b shows up 3 times in df1 and 2 times in df3, so we get 6 occurrences in the result of the merge)
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6
#   key  data2
# 0   a      0
# 1   b      1
# 2   b      2
# 3   d      3
#   key  data1  data2
# 0   b      0      1
# 1   b      0      2
# 2   b      1      1
# 3   b      1      2
# 4   b      6      1
# 5   b      6      2
# 6   a      2      0
# 7   a      4      0
# 8   a      5      0

# %%
# There are several types of joins: left, right, inner, and outer. Let's compare them.
# How does a 'left' join compare to our initial join?  Note that it keeps the result if it shows up in df1,
# regardless of whether it also shows up in df2.  It fills in a value of NaN for the missing value from df2.
pd.merge(df1,df3, on='key', how='left')
# Out:
#   key  data1  data2
# 0   b      0    1.0
# 1   b      0    2.0
# 2   b      1    1.0
# 3   b      1    2.0
# 4   a      2    0.0
# 5   c      3    NaN
# 6   a      4    0.0
# 7   a      5    0.0
# 8   b      6    1.0
# 9   b      6    2.0

# %%
#How does a 'right' join compare?  Same idea, but this time it keeps a result if it shows up in df2, regardless
# of whether it also shows up in df1.
pd.merge(df1,df3, on='key', how='right')
# Out:
#   key  data1  data2
# 0   b    0.0      1
# 1   b    1.0      1
# 2   b    6.0      1
# 3   b    0.0      2
# 4   b    1.0      2
# 5   b    6.0      2
# 6   a    2.0      0
# 7   a    4.0      0
# 8   a    5.0      0
# 9   d    NaN      3

# %%
#How does an 'inner' join compare?
pd.merge(df1,df3, on='key', how='inner')
# seems to be the default argument...
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      0      2
# 2   b      1      1
# 3   b      1      2
# 4   b      6      1
# 5   b      6      2
# 6   a      2      0
# 7   a      4      0
# 8   a      5      0

# %%
#How does an 'outer' join compare?  If inner joins are like an intersection of two sets, outer joins are unions.
pd.merge(df1,df3, on='key', how='outer')
# Out:
#    key  data1  data2
# 0    b    0.0    1.0
# 1    b    0.0    2.0
# 2    b    1.0    1.0
# 3    b    1.0    2.0
# 4    b    6.0    1.0
# 5    b    6.0    2.0
# 6    a    2.0    0.0
# 7    a    4.0    0.0
# 8    a    5.0    0.0
# 9    c    3.0    NaN
# 10   d    NaN    3.0

# %%
#What if the join fields have different names?  No problem - just specify the names.
df4 = pd.DataFrame({'key_1': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],'data1': range(7)})
df5 = pd.DataFrame({'key_2': ['a', 'b', 'b', 'd'],'data2': range(4)})
pd.merge(df4,df5, left_on='key_1', right_on='key_2')
# Out:
#   key_1  data1 key_2  data2
# 0     b      0     b      1
# 1     b      0     b      2
# 2     b      1     b      1
# 3     b      1     b      2
# 4     b      6     b      1
# 5     b      6     b      2
# 6     a      2     a      0
# 7     a      4     a      0
# 8     a      5     a      0

# %%
# Here is an example that uses a combination of a data column and an index to merge two dataframes.
df4 = pd.DataFrame({'key_1': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],'data1': range(7)})
df5 = pd.DataFrame({'data2': [4,6,8,10]}, index=['a','b','c','d'])
pd.merge(df4,df5, left_on='key_1', right_index=True)
# Out:
#   key_1  data1  data2
# 0     b      0      6
# 1     b      1      6
# 6     b      6      6
# 2     a      2      4
# 4     a      4      4
# 5     a      5      4
# 3     c      3      8

# %% [markdown]
# ## Concatenating

# %%
# Concatenating can append rows, or columns, depending on which axis you use. Default is 0
s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
s3 = pd.Series([5, 6], index=['f', 'g'])
pd.concat([s1, s2, s3])
# Since we are concatenating series on axis 0, this creates a longer series, appending each of the three series
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# dtype: int64

# %%
# What if we concatenate on axis 1?
pd.concat([s1, s2, s3], axis=1)
# Out:
# C:\Users\hishamur.Ishrat\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
# Outer join is the default:
pd.concat([s1, s2, s3], axis=1, join='outer')
# Out:
# C:\Users\hishamur.Ishrat\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
# What would an inner join produce?
pd.concat([s1, s2, s3], axis=1, join='inner')
# Out:
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []

# %%
# We need some overlapping values to have the inner join produe non-empty results
s4 = pd.Series([4, 5, 6], index=['c', 'd', 'e'])
s5 = pd.Series([1, 2, 3], index=['d', 'e', 'f'])
s6 = pd.Series([7, 8, 9, 10], index=['d', 'e', 'f', 'g'])
pd.concat([s4, s5, s6], axis=1, join='outer')
# Out:
# C:\Users\hishamur.Ishrat\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """
#      0    1     2
# c  4.0  NaN   NaN
# d  5.0  1.0   7.0
# e  6.0  2.0   8.0
# f  NaN  3.0   9.0
# g  NaN  NaN  10.0

# %%
# Here is the inner join 
pd.concat([s4, s5, s6], axis=1, join='inner')
# Note that it contains only entries that overlap in all three series.
# Out:
#    0  1  2
# d  5  1  7
# e  6  2  8

# %% [markdown]
# ## Reshaping with Hierarchical Indexing

# %%
data = pd.DataFrame(np.arange(6).reshape((2, 3)),
                 index=pd.Index(['Ohio', 'Colorado'], name='state'),
                 columns=pd.Index(['one', 'two', 'three'], name='number'))
data
# Out:
# number    one  two  three
# state
# Ohio        0    1      2
# Colorado    3    4      5

# %%
# Stack pivots the columns into rows, producing a Series with a hierarchical index:
result = data.stack()
result
# Out:
# state     number
# Ohio      one       0
#           two       1
#           three     2
# Colorado  one       3
#           two       4
#           three     5
# dtype: int32

# %%
# Unstack reverses this process:
result.unstack()
# Out:
# number    one  two  three
# state
# Ohio        0    1      2
# Colorado    3    4      5

# %% [markdown]
# See also the related pivot method

# %% [markdown]
# ## Data Transformations

# %%
# Start with a dataframe containing some duplicate values
data = pd.DataFrame({'k1': ['one'] * 3 + ['two'] * 4,'k2': [1, 1, 2, 3, 3, 4, 99]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  one   1
# 2  one   2
# 3  two   3
# 4  two   3
# 5  two   4
# 6  two  99

# %%
# How to see which rows contain duplicate values
data.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# dtype: bool

# %%
# How to remove duplicate values
data.drop_duplicates()

# %%
#If 99 is a code for missing data, we could replace any such values with NaNs
data['k2'].replace(99,np.nan)

# %% [markdown]
# ## Categorization (binning)

# %%
# Let's look at how to create categories of data using ranges to bin the data using cut
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]
bins = [18, 25, 35, 60, 100]
cats = pd.cut(ages, bins)
type(cats)
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
cats.categories
# Out:
# IntervalIndex([(18, 25], (25, 35], (35, 60], (60, 100]]
#               closed='right',
#               dtype='interval[int64]')

# %%
cats.codes
# Out:
# array([0, 0, 0, 1, 0, 0, 2, 1, 3, 2, 2, 1], dtype=int8)

# %%
pd.value_counts(cats)
# Out:
# (18, 25]     5
# (35, 60]     3
# (25, 35]     3
# (60, 100]    1
# dtype: int64

# %%
# Consistent with mathematical notation for intervals, a parenthesis means that the side is open while the 
#square bracket means it is closed (inclusive). Which side is closed can be changed by passing right=False:
cats = pd.cut(ages, bins, right=False)
print(ages)
print(pd.value_counts(cats))
# Out:
# [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]
# [25, 35)     4
# [18, 25)     4
# [35, 60)     3
# [60, 100)    1
# dtype: int64

# %% [markdown]
# ### Removing Outliers

# %%
# Start by creating a dataframe with 4 columns of 1,000 random numbers
# We'll use a fixed seed for the random number generator to get repeatable results
np.random.seed(12345)
data = pd.DataFrame(np.random.randn(1000, 4))
data.describe()
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.067684     0.067924     0.025598    -0.002298
# std       0.998035     0.992106     1.006835     0.996794
# min      -3.428254    -3.548824    -3.184377    -3.745356
# 25%      -0.774890    -0.591841    -0.641675    -0.644144
# 50%      -0.116401     0.101143     0.002073    -0.013611
# 75%       0.616366     0.780282     0.680391     0.654328
# max       3.366626     2.653656     3.260383     3.927528

# %%
# This identifies any values in column 3 with absolute values > 3
col = data[3]
col[np.abs(col) > 3]
# Out:
# 97     3.927528
# 305   -3.399312
# 400   -3.745356
# Name: 3, dtype: float64

# %%
# This identifies all the rows with any column containing absolute values > 3
data[(np.abs(data) > 3).any(1)]
# Out:
#             0         1         2         3
# 5   -0.539741  0.476985  3.248944 -1.021228
# 97  -0.774363  0.552936  0.106061  3.927528
# 102 -0.655054 -0.565230  3.176873  0.959533
# 305 -2.315555  0.457246 -0.025907 -3.399312
# 324  0.050188  1.951312  3.260383  0.963301
# 400  0.146326  0.508391 -0.196713 -3.745356
# 499 -0.293333 -0.242459 -3.056990  1.918403
# 523 -3.428254 -0.296336 -0.439938 -0.867165
# 586  0.275144  1.179227 -3.184377  1.369891
# 808 -0.362528 -3.548824  1.553205 -2.186301
# 900  3.366626 -2.372214  0.851010  1.332846

# %%
# Now we can cap the values at -3 to 3 using this:
data[np.abs(data) > 3] = np.sign(data) * 3
data.describe()
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.067623     0.068473     0.025153    -0.002081
# std       0.995485     0.990253     1.003977     0.989736
# min      -3.000000    -3.000000    -3.000000    -3.000000
# 25%      -0.774890    -0.591841    -0.641675    -0.644144
# 50%      -0.116401     0.101143     0.002073    -0.013611
# 75%       0.616366     0.780282     0.680391     0.654328
# max       3.000000     2.653656     3.000000     3.000000

# %% [markdown]
# ### Computing Dummy Variables

# %%
df = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'b'],'data1': range(6)})
df
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   b      5

# %%
# This generates dummy variables for each value of key
# Dummy variables are useful in statistical modeling, to have 0/1 indicator
# variables for the presence of some condition
pd.get_dummies(df['key'])
# Out:
#    a  b  c
# 0  0  1  0
# 1  0  1  0
# 2  1  0  0
# 3  0  0  1
# 4  1  0  0
# 5  0  1  0

# %%
# This generates dummy variables for each value of key and appends these to the dataframe
dummies = pd.get_dummies(df['key'], prefix='key')
df_with_dummy = df[['data1']].join(dummies)
df_with_dummy
# Out:
#    data1  key_a  key_b  key_c
# 0      0      0      1      0
# 1      1      0      1      0
# 2      2      1      0      0
# 3      3      0      0      1
# 4      4      1      0      0
# 5      5      0      1      0

# %% [markdown]
# Notice that we used join instead of merge.  The join method is very similar to merge, but uses indexes to merge, by default.  From the documentation:
#
# http://pandas.pydata.org/pandas-docs/stable/merging.html#database-style-dataframe-joining-merging
# merge is a function in the pandas namespace, and it is also available as a DataFrame instance method, with the calling DataFrame being implicitly considered the left object in the join.
#
# The related DataFrame.join method, uses merge internally for the index-on-index and index-on-column(s) joins, but joins on indexes by default rather than trying to join on common columns (the default behavior for merge). If you are joining on index, you may wish to use DataFrame.join to save yourself some typing

# %% [markdown]
# ## A bit more:
# 1. Filter out records with more than 4 bedrooms
# 2. Create dummy variables for each bedroom count (e.g. bed_1 would have 1 for rows with 1 bedroom, 0 for others), and merge them with the dataframe
# 3. Filter sqft < 500 and > 3000
# 4. Create a set of 5 bins for price and do counts of how many records are in each category

# %%
import re as re, pandas as pd, numpy as np
cl = pd.read_csv('items.csv')
for i in cl['bedrooms'].index:
    r = re.search('(?<=\/ )(.*)(?=br)', cl.loc[i,'bedrooms'])
    cl.loc[i,'bedrooms'] = r.group(0) if r else np.nan

for i in cl['sqft'].index:
    r = re.search('(\d+)(?=ft² -)', cl.loc[i,'sqft'])
    cl.loc[i,'sqft'] = r.group(1) if r else np.nan
    
cl=cl.fillna(0)    
cl['bedrooms']=cl['bedrooms'].astype(int)
cl['sqft']=cl['sqft'].astype(int)
cl[cl['bedrooms'] > 4]

df = cl[cl['bedrooms'] <= 4]
df[:100]
# Out:
#                        neighborhood  \
# 0              (SOMA / south beach)
# 1              (SOMA / south beach)
# 2             (inner sunset / UCSF)
# 3              (financial district)
# 4                  (lower nob hill)
# 5               (sunset / parkside)
# 6              (SOMA / south beach)
# 7                    (russian hill)
# 8                                 0
# 9                 (pacific heights)
# 10             (SOMA / south beach)
# 11            (marina / cow hollow)
# 12             (SOMA / south beach)
# 13              (sunset / parkside)
# 14    (downtown / civic / van ness)
# 15    (downtown / civic / van ness)
# 16             (SOMA / south beach)
# 17             (SOMA / south beach)
# 18       (twin peaks / diamond hts)
# 19          (castro / upper market)
# 20             (financial district)
# 21            (richmond / seacliff)
# 22                (pacific heights)
# 23             (SOMA / south beach)
# 24          (castro / upper market)
# 25          (castro / upper market)
# 26                      (glen park)
# 27       (twin peaks / diamond hts)
# 28             (SOMA / south beach)
# 29            (marina / cow hollow)
# ..                              ...
# 70      (Alta Loma & Eastmoor Ave.)
# 71            (marina / cow hollow)
# 72             (SOMA / south beach)
# 73             (SOMA / south beach)
# 74             (SOMA / south beach)
# 75       (twin peaks / diamond hts)
# 76          (castro / upper market)
# 77             (SOMA / south beach)
# 78    (downtown / civic / van ness)
# 79                     (noe valley)
# 80             (SOMA / south beach)
# 81            (richmond / seacliff)
# 82            (alamo square / nopa)
# 83    (downtown / civic / van ness)
# 86            (alamo square / nopa)
# 87       (twin peaks / diamond hts)
# 88               (mission district)
# 89            (marina / cow hollow)
# 90      (cole valley / ashbury hts)
# 91                (pacific heights)
# 92                (pacific heights)
# 93                       (nob hill)
# 94      (west portal / forest hill)
# 95                       (nob hill)
# 96                   (lower haight)
# 97      (cole valley / ashbury hts)
# 98              (visitacion valley)
# 99            (marina / cow hollow)
# 100               (USF / panhandle)
# 101               (USF / panhandle)
#
#                                                  title   price  bedrooms  \
# 0                     1bed + Den, 1bath at Mission Bay   $2895         1
# 1                                 Love where you live!   $3354         1
# 2           We Welcome Your Furry Friends! Call Today!   $2865         1
# 3    Golden Gateway Commons | 2BR + office townhous...   $5500         2
# 4           Experience Luxury Living in San Fransisco!   $3892         2
# 5                               $1250 - 1 bdrm, 1 bath   $1250         1
# 6                     Made For The Die-hard Giants Fan   $3249         0
# 7                              Open Concept 1bed 1bath   $2690         1
# 8    Contemporary, charming 2bds/1ba with private d...   $2850         2
# 9    2bd/2.5ba, 2 car tandem parking @ 1998 Broadwa...   $6500         2
# 10   Stunning Modern GARDEN Loft! Upgrades, Views &...   $4100         1
# 11          $4700. Top Flat, remodeled, newer building   $4700         2
# 12                   2/Bed  Room /2Bath Room Apartment   $4500         2
# 13                Central Sunset Top unit Flat 1Br 1Ba   $2200         1
# 14   Nice Jr 1 Bedroom: bright/spacious/hardwoods/p...   $2095         1
# 15   Nice STUDIO- bright/spacious/hardwoods/great l...   $1600         0
# 16   Furnished B&T loft w/ office+patio *10-12mo le...   $5500         1
# 17                        Channel Your Inner Explorer    $3274         1
# 18   Remodeled Clarendon Heights Home with VIEWS; G...   $8200         3
# 19   Luxury Home in Clarendon Heights with VIEWS; P...   $8200         3
# 20   Modern 1 BD/ 1 BA condo in a historic building...   $2995         1
# 21   Bright and Spacious Top Floor Studio, Hardwood...   $1695         0
# 22   Remodeled Two Bedroom With New Carpet & Parkin...   $3000         2
# 23         Live/Work Loft + HUGE 400 Sqft Patio *PICS*   $3900         1
# 24   NEWLY REDECORATED WITH GARDEN VIEWS - GREAT LO...   $2400         1
# 25   Gorgeous furnished townhouse with private elev...  $10000         3
# 26                Exquisite Furnished home.  ~ J.Wavro   $9750         4
# 27   Large Miraloma Park 4bd/3ba single family home...   $4950         4
# 28       Full floor flat - 1 bedroom 1 bath  ~ J.Wavro   $4200         1
# 29   Top floor remodeled studio. Available October ...   $2150         0
# ..                                                 ...     ...       ...
# 70                             Daly City home for rent   $3000         3
# 71                                    Prime Cow Hollow   $8975         3
# 72                    Updated Top Floor Studio 9/15/13   $3219         0
# 73   Infinity Luxury - great location, parking, gym...   $3900         1
# 74   23rd Floor alcove corner 1bedroom w/ $0 deposit!*   $3650         1
# 75        Suburban City Life. The Best of Both Worlds!   $2625         1
# 76                       2-Bedroom Castro/Upper Market   $2950         2
# 77   Private 250 Sq Ft Patio - Modern Full Service ...   $3300         1
# 78                        NEW Studio w/ AMAZING Views!   $2436         0
# 79   Completely Remodeled Large Top Floor Flat in N...   $5995         3
# 80                     Close proximity to everything!    $4373         2
# 81                                UNIQUE BI-LEVEL UNIT   $2000         1
# 82   Large 3BR flat with classic SF charm, near USF...   $4495         3
# 83   Remodeled Studio w/ Hrdwd Floors available ~ J...   $1650         0
# 86         Remodeled 1/1+office w/ park view ~ J.Wavro   $3450         1
# 87   YOU Gottah See IT~Panorama VIEW~Private Huge D...   $2950         1
# 88            Mission Doloras 2 DR-1Bath Condo  $5,500   $5500         2
# 89           ID#1103: Cw Hlw 1BR w/Shrd Gdn Patio &Pkg   $2750         1
# 90                 Beautiful 2 bed/2 bath Owner's Unit   $5800         2
# 91           ID#1400: Remodeled 1BR/1BA Spacious Condo   $4000         1
# 92   ID#1399: Pacific Heights Furnished 1BR/1BA Gar...   $4000         1
# 93        ID#1385: Large 2BR Remodeled Apt w/SF Charm!   $3950         2
# 91      0  http://sfbay.craigslist.org/sfc/apa/index500.html
# 92      0  http://sfbay.craigslist.org/sfc/apa/index500.html
# 93      0  http://sfbay.craigslist.org/sfc/apa/index500.html
# 94   1900  http://sfbay.craigslist.org/sfc/apa/index400.html
# 95      0  http://sfbay.craigslist.org/sfc/apa/index400.html
# 96      0  http://sfbay.craigslist.org/sfc/apa/index400.html
# 97      0  http://sfbay.craigslist.org/sfc/apa/index400.html
# 98   1904  http://sfbay.craigslist.org/sfc/apa/index400.html
# 99    500  http://sfbay.craigslist.org/sfc/apa/index400.html
# 100     0  http://sfbay.craigslist.org/sfc/apa/index400.html
# 101     0  http://sfbay.craigslist.org/sfc/apa/index400.html
#
# [100 rows x 11 columns]

# %%
dummies = pd.get_dummies(df['bedrooms'], prefix='bed')
df_with_dummy = df.join(dummies)
df_with_dummy
# Out:
#                         neighborhood  \
# 0               (SOMA / south beach)
# 1               (SOMA / south beach)
# 2              (inner sunset / UCSF)
# 3               (financial district)
# 4                   (lower nob hill)
# 5                (sunset / parkside)
# 6               (SOMA / south beach)
# 7                     (russian hill)
# 8                                  0
# 9                  (pacific heights)
# 10              (SOMA / south beach)
# 11             (marina / cow hollow)
# 12              (SOMA / south beach)
# 13               (sunset / parkside)
# 14     (downtown / civic / van ness)
# 15     (downtown / civic / van ness)
# 16              (SOMA / south beach)
# 17              (SOMA / south beach)
# 18        (twin peaks / diamond hts)
# 19           (castro / upper market)
# 20              (financial district)
# 21             (richmond / seacliff)
# 22                 (pacific heights)
# 23              (SOMA / south beach)
# 24           (castro / upper market)
# 25           (castro / upper market)
# 26                       (glen park)
# 27        (twin peaks / diamond hts)
# 28              (SOMA / south beach)
# 29             (marina / cow hollow)
# ..                               ...
# 970                   (potrero hill)
# 971            (alamo square / nopa)
# 972                   (potrero hill)
# 973             (SOMA / south beach)
# 974      (cole valley / ashbury hts)
# 975        (ingleside / SFSU / CCSF)
# 976            (alamo square / nopa)
# 977            (richmond / seacliff)
# 978              (sunset / parkside)
# 979   (north beach / telegraph hill)
# 980            (alamo square / nopa)
# 981            (marina / cow hollow)
# 982                     (noe valley)
# 983             (SOMA / south beach)
# 984            (inner sunset / UCSF)
# 985            (richmond / seacliff)
# 986            (richmond / seacliff)
# 987             (SOMA / south beach)
# 988             (SOMA / south beach)
# 989            (alamo square / nopa)
# 990                   (russian hill)
# 991        (ingleside / SFSU / CCSF)
# 992             (financial district)
# 993                        (bayview)
# 994                       (nob hill)
# 995                   (russian hill)
# 996                 (bernal heights)
# 997                 (haight ashbury)
# 998            (marina / cow hollow)
# 999                (pacific heights)
#
#                                                  title   price  bedrooms  \
# 0                     1bed + Den, 1bath at Mission Bay   $2895         1
# 1                                 Love where you live!   $3354         1
# 2           We Welcome Your Furry Friends! Call Today!   $2865         1
# 3    Golden Gateway Commons | 2BR + office townhous...   $5500         2
# 4           Experience Luxury Living in San Fransisco!   $3892         2
# 5                               $1250 - 1 bdrm, 1 bath   $1250         1
# 6                     Made For The Die-hard Giants Fan   $3249         0
# 7                              Open Concept 1bed 1bath   $2690         1
# 8    Contemporary, charming 2bds/1ba with private d...   $2850         2
# 9    2bd/2.5ba, 2 car tandem parking @ 1998 Broadwa...   $6500         2
# 10   Stunning Modern GARDEN Loft! Upgrades, Views &...   $4100         1
# 11          $4700. Top Flat, remodeled, newer building   $4700         2
# 12                   2/Bed  Room /2Bath Room Apartment   $4500         2
# 13                Central Sunset Top unit Flat 1Br 1Ba   $2200         1
# 14   Nice Jr 1 Bedroom: bright/spacious/hardwoods/p...   $2095         1
# 15   Nice STUDIO- bright/spacious/hardwoods/great l...   $1600         0
# 16   Furnished B&T loft w/ office+patio *10-12mo le...   $5500         1
# 17                        Channel Your Inner Explorer    $3274         1
# 18   Remodeled Clarendon Heights Home with VIEWS; G...   $8200         3
# 19   Luxury Home in Clarendon Heights with VIEWS; P...   $8200         3
# 20   Modern 1 BD/ 1 BA condo in a historic building...   $2995         1
# 21   Bright and Spacious Top Floor Studio, Hardwood...   $1695         0
# 22   Remodeled Two Bedroom With New Carpet & Parkin...   $3000         2
# 23         Live/Work Loft + HUGE 400 Sqft Patio *PICS*   $3900         1
# 24   NEWLY REDECORATED WITH GARDEN VIEWS - GREAT LO...   $2400         1
# 25   Gorgeous furnished townhouse with private elev...  $10000         3
# 26                Exquisite Furnished home.  ~ J.Wavro   $9750         4
# 27   Large Miraloma Park 4bd/3ba single family home...   $4950         4
# 28       Full floor flat - 1 bedroom 1 bath  ~ J.Wavro   $4200         1
# 29   Top floor remodeled studio. Available October ...   $2150         0
# ..                                                 ...     ...       ...
# 970                          Potrero Hill 2 bed 2 bath   $3995         2
# 971         Wanted: Room/Studio near Alamo Square Park   $1500         0
# 972  Unique House w/ Roof Decks & Amazing Views **V...   $5995         2
# 973  COME RENT!!!  NEW Studios w IN UNIT washer dryer!   $2426         0
# 974  Spectacular 4 bedroom house with amazing view ...   $6495         4
# 975                   2BR/2BA Dynamic Townhouse in SF    $2900         2
# 976     3rd Floor Apt with two 2 master bedroom suites   $4800         2
# 977  Upscale Studio - Heated Floors, New Kitchen & ...   $1675         0
# 978  Spacious Studio with Parking at Lakewood Apart...   $1739         0
# 979       Modern North Beach 2BR/2BA including parking   $4600         2
# 980  NOPA location-Bright and Sunny-Garden-Rent inc...   $2595         1
# 981                TOP Floor Flat - Views!  2 Bedrooms   $5600         2
# 982       Quiet Hill Top Building, Parking, GREAT VIEW   $2795         1
# 983  Gorgeous Bay Bridge View with Amazing Interior...   $3616         1
# 984             nice 1 bdr 1 bath on 16th ave & Irving   $1995         1
# 985  Top Floor 1BR with Hardwood Floors and Walk-in...   $2095         1
# 986  Secluded 1BR Bungalow w/ updated kitchen//Avai...   $1950         1
# 987  Great views from the 11th floor. awsome floor ...   $3290         1
# 988  South Beach MarinaApartment - best views, don'...   $4425         2
# 989  Large, quiet Edwardian 1BR//Available Now//One...   $2250         1
# 990  Great 1 bedroom with Golden Gate Bridge and Ci...   $3800         1
# 23              (SOMA / south beach)
# 34              (financial district)
# 37                      (noe valley)
# 41             (alamo square / nopa)
# 43                    (russian hill)
# 46             (richmond / seacliff)
# 48              (SOMA / south beach)
# 56              (SOMA / south beach)
# 57             (inner sunset / UCSF)
# 58             (richmond / seacliff)
# 60              (financial district)
# 62       (excelsior / outer mission)
# 65             (richmond / seacliff)
# 70       (Alta Loma & Eastmoor Ave.)
# 71             (marina / cow hollow)
# 72              (SOMA / south beach)
# 74              (SOMA / south beach)
# 75        (twin peaks / diamond hts)
# 76           (castro / upper market)
# ..                               ...
# 915    (downtown / civic / van ness)
# 918                 (haight ashbury)
# 919            (inner sunset / UCSF)
# 928                 (bernal heights)
# 930                (USF / panhandle)
# 932                       (nob hill)
# 933             (SOMA / south beach)
# 934                  (lower pac hts)
# 937                 (bernal heights)
# 940        (ingleside / SFSU / CCSF)
# 941            (inner sunset / UCSF)
# 943             (SOMA / south beach)
# 950             (SOMA / south beach)
# 951             (SOMA / south beach)
# 953          (laurel hts / presidio)
# 955              (sunset / parkside)
# 960                       (nob hill)
# 963                 (inner richmond)
# 969                 (inner richmond)
# 970                   (potrero hill)
# 975        (ingleside / SFSU / CCSF)
# 976            (alamo square / nopa)
# 978              (sunset / parkside)
# 979   (north beach / telegraph hill)
# 981            (marina / cow hollow)
# 982                     (noe valley)
# 983             (SOMA / south beach)
# 984            (inner sunset / UCSF)
# 988             (SOMA / south beach)
# 992             (financial district)
#
#                                                  title  price  bedrooms  \
# 0                     1bed + Den, 1bath at Mission Bay  $2895         1
# 1                                 Love where you live!  $3354         1
# 2           We Welcome Your Furry Friends! Call Today!  $2865         1
# 3    Golden Gateway Commons | 2BR + office townhous...  $5500         2
# 6                     Made For The Die-hard Giants Fan  $3249         0
# 7                              Open Concept 1bed 1bath  $2690         1
# 9    2bd/2.5ba, 2 car tandem parking @ 1998 Broadwa...  $6500         2
# 11          $4700. Top Flat, remodeled, newer building  $4700         2
# 12                   2/Bed  Room /2Bath Room Apartment  $4500         2
# 14   Nice Jr 1 Bedroom: bright/spacious/hardwoods/p...  $2095         1
# 17                        Channel Your Inner Explorer   $3274         1
# 23         Live/Work Loft + HUGE 400 Sqft Patio *PICS*  $3900         1
# 34   Millennium Tower Luxury Condo - 3 Bedrooms/3 B...  $7500         3
# 37           Charming Noe Valley 2 bdrm Victorian Flat  $3900         2
# 41                    Remodeled Furnished Sunny Studio  $2600         0
# 43                     Prime Russian Hill garden flat   $5300         2
# 46   Very nice large modern 4 bedrooms  2.5 baths f...  $3800         4
# 48       Treat yourself to the apartment you deserve!   $3169         1
# 56   Sunny South-facing 1-bedrm with Floor-to-Ceili...  $3115         1
# 57                                     Studio for rent  $1300         0
# 58   Sunny Entire Top Story 2BR+1Bath Flat, Views f...  $2450         2
# 60   Spacious, Amazing Views of the North Bay, Ferr...  $5135         2
# 62                   Immaculate 2 bd / 2ba Family Home  $2500         2
# 65                        Large 2 BR/1 BA with Parking  $2650         2
# 70                             Daly City home for rent  $3000         3
# 71                                    Prime Cow Hollow  $8975         3
# 72                    Updated Top Floor Studio 9/15/13  $3219         0
# 74   23rd Floor alcove corner 1bedroom w/ $0 deposit!*  $3650         1
# 75        Suburban City Life. The Best of Both Worlds!  $2625         1
# 76                       2-Bedroom Castro/Upper Market  $2950         2
# ..                                                 ...    ...       ...
# 915        Beautiful Home In Down Town SF. Avail.Now!!  $3128         1
# 918                 Large, Modern Unit - lots of light  $3150         1
# 919  Avalon Sunset Towers offers Gated Entrance and...  $2705         1
# 928  Beautiful 3 bed 2 bath with office/parking/gar...  $5295         3
# 930  7br/3.5ba ►PHOTOS ►OPEN HOME THURSDAY ►Remodel...  $8999         7
# 932  Retro Chic 3 bed 3 ba Condo w/ Views, Gym, Poo...  $6995         3
# 933               Beautiful loft - Move in immediately  $3446         1
# 934        2BR/2BA *Furnished* Spacious Flat for Rent   $5480         2
# 937  Beautiful updated  with top appliances Victori...  $3950         2
# 940  Comfortable 3-4 Bedroom House On Victoria @ Ho...  $3300         4
# 941  Plenty of Closet Space in this Large Renovated...  $2805         1
# 943  2bd/2ba, city and Twin Peak views, One Rincon ...  $5700         2
# 950                      Brand New With Gorgeous Views  $3674         1
# 951                            Sunny Second Floor Home  $4373         2
# 953  Spaciou, modern 2 bdr 1bath w/ Wood Floors nea...  $3400         2
# 955  Over 2300sqft!! Elegant and spacious 2 story h...  $4750         5
# 960          2 Bed/1 Bath on Best Block. Walk Downtown  $3600         2
# 963  CLASSIC DECO BEAUTY INC PARKING GG BRIDGE VU 3...  $2750         1
# 969  CLASSIC BEAUTY CUSTOM PAINT  GG BRIDGE VU 3 CL...  $2450         1
# 970                          Potrero Hill 2 bed 2 bath  $3995         2
# 975                   2BR/2BA Dynamic Townhouse in SF   $2900         2
# 976     3rd Floor Apt with two 2 master bedroom suites  $4800         2
# 978  Spacious Studio with Parking at Lakewood Apart...  $1739         0
# 979       Modern North Beach 2BR/2BA including parking  $4600         2
# 981                TOP Floor Flat - Views!  2 Bedrooms  $5600         2
# 982       Quiet Hill Top Building, Parking, GREAT VIEW  $2795         1
# 983  Gorgeous Bay Bridge View with Amazing Interior...  $3616         1
# 984             nice 1 bdr 1 bath on 16th ave & Irving  $1995         1
# 988  South Beach MarinaApartment - best views, don'...  $4425         2
# 992            Millennium Tower with parking and views  $6700         2
#
#             pid   longitude         date                      link   latitude  \
# 0    4046628359 -122.399663  Sep  4 2013  /sfc/apa/4046628359.html  37.774623
# 1    4046761563    0.000000  Sep  4 2013  /sfc/apa/4046761563.html   0.000000
# 2    4046661504 -122.470727  Sep  4 2013  /sfc/apa/4046661504.html  37.765739
# 3    4036170429    0.000000  Sep  4 2013  /sfc/apa/4036170429.html   0.000000
# 6    4046730047 -122.389798  Sep  4 2013  /sfc/apa/4046730047.html  37.774192
# 7    4046570245 -122.420787  Sep  4 2013  /sfc/apa/4046570245.html  37.796034
# 9    4046018830 -122.429850  Sep  4 2013  /sfc/apa/4046018830.html  37.794973
